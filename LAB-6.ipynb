# %%
#task1
a_tuple = ("The Institute", ("Best Mystery & Thriller", "The Silent Patient", 68821), 75717,
[1, 2, 3, 400, 5, 6, 7], ("Best Fiction", "The Testaments", 98291))
print(f"Output: {a_tuple[3][3]}")
# Out:
# Output: 400

# %%
#task2
tuple1=(10, 20, 24, 25, 26, 35, 70)
if(len(tuple1)>=4):
  print(tuple1[2:-2:])
else:
  pass
# Out:
# (24, 25, 26)

# %%
#Task3
book_info = (
("Best Mystery & Thriller","The Silent Patient",68,821),
("Best Horror","The Institute",75,717),
("Best History & Biography","The five",31,783 ),
("Best Fiction","The Testaments",98,291)
)
print(f"Size of the tuple is: {len(book_info)}")
for i in book_info:
  print (i)
# Out:
# Size of the tuple is: 4
# ('Best Mystery & Thriller', 'The Silent Patient', 68, 821)
# ('Best Horror', 'The Institute', 75, 717)
# ('Best History & Biography', 'The five', 31, 783)
# ('Best Fiction', 'The Testaments', 98, 291)

# %%
#taks4
book_info = (
("Best Mystery & Thriller","The Silent Patient",68821),
("Best Horror","The Institute",75717),
("Best History & Biography","The five",31783 ),
("Best Fiction","The Testaments",98291)
) 
for k in book_info:
  a,b,c=k
  print(f"{b} won the {a} category with {c} votes")
# Out:
# The Silent Patient won the Best Mystery & Thriller category with 68821 votes
# The Institute won the Best Horror category with 75717 votes
# The five won the Best History & Biography category with 31783 votes
# The Testaments won the Best Fiction category with 98291 votes

# %%
#task5
Given_tuple= (10, 8, 5, 2, 10, 15, 10, 8, 5, 8, 8, 2)
f=int(input())
l=[]
for k in Given_tuple:
  if k==f:
    l.append(k)
  else:
    pass
print(f"{f} appears {len(l)} times in the tuple")
# Out:
# 8
# 8 appears 4 times in the tuple

# %%
#Task 6
Given_tuple= ('a', 'b', 'c', 'd', 'e', 'f', 'g', 'h')
gh=list(Given_tuple)
kh=[]
for l in gh[::-1]:
  kh.append(l)
print(tuple(kh))
# Out:
# ('h', 'g', 'f', 'e', 'd', 'c', 'b', 'a')

# %%
#task7
boy={'Harry':15, 'Draco':8, 'Nevil':19}
girl={'Ginie':18, 'Luna': 14}
all=boy.copy()
all.update(girl)
print (all)
# Out:
# {'Harry': 15, 'Draco': 8, 'Nevil': 19, 'Ginie': 18, 'Luna': 14}

# %%
#task7
boy={'Harry':15, 'Draco':8, 'Nevil':19}
girl={'Ginie':18, 'Luna': 14}
all={}
for key,value in boy.items():
  all[key]=value
for key,value in girl.items():
  all[key]=value
print (all)
# Out:
# {'Harry': 15, 'Draco': 8, 'Nevil': 19, 'Ginie': 18, 'Luna': 14}

# %%
#task8
sum=0
string1=input()
list1=string1.split(",")
dict2={}
print (list1)
for i in list1:
  a,b=i.split(":")
  dict2[a]=int(b)
print(dict2)
for k in dict2.items():
  a,b=k
  sum+=b
avarage=sum/len(dict2)
print (f"Average is {int(avarage)}.")
# Out:
# Jon:100, Dan:200, Rob:30, Ned:110
# ['Jon:100', ' Dan:200', ' Rob:30', ' Ned:110']
# {'Jon': 100, ' Dan': 200, ' Rob': 30, ' Ned': 110}
# Average is 110.

# %%
#task9
exam_marks = {'Cierra Vega': 175, 'Alden Cantrell': 200, 'Kierra Gentry': 165, 'Pierre Cox': 190}
final_result={}
chvalue=int(input())
for key,value in exam_marks.items():
  if (value>=chvalue):
    final_result[key]=value
  else:
    pass
print (final_result)
# Out:
# 190
# {'Alden Cantrell': 200, 'Pierre Cox': 190}

# %%
#task10
max=0
cache=0
d={'sci fi': 5, 'mystery': 3, 'horror': 14, 'young_adult': 2, 'adventure':9}

for key,value in d.items():
    if(cache - int(value)>0):
      max=cache
    else:
      max=max
      cache=int(value)
print(f"The highest selling book genre is 'mystery' and the number of books sold are {max}.")
# Out:
# The highest selling book genre is 'mystery' and the number of books sold are 14.

# %%
#task11
g=input()
A=[]
h=""
k={}
g=g.lower()
for i in g:
  for p in g:
    if (i==p):
      h=h+p
    else:
      pass
  k[i]=len(h)
  h=""
print (k)
# Out:
# Python programming is fun
# {'p': 2, 'y': 1, 't': 1, 'h': 1, 'o': 2, 'n': 3, ' ': 3, 'r': 2, 'g': 2, 'a': 1, 'm': 2, 'i': 2, 's': 1, 'f': 1, 'u': 1}

# %%
#task12
dict_1 = {'A': [1, 2, 3], 'b': ['1', '2'], "c": [4, 5, 6, 7]}
c=0
for i in dict_1.items():
  a,b=i
  for i in b:
    c=c+1
print (c)
# Out:
# 9

# %%
#task13
list_1 = [("a", 1), ("b", 2), ("a", 3), ("b", 1), ("a", 2), ("c", 1)]
dist_1={}
k=[]
for i in list_1:
  d,e=i
  for j in list_1:
    p,f=j
    if(d==p):
      k.append(f)
  dist_1[d]=k
  k=[]
print (dist_1)
# Out:
# {'a': [1, 3, 2], 'b': [2, 1], 'c': [1]}
