# %%
#prework
list1= input()
list2=[]
index=0
for i in range (0,len(list1),1):
    if(list1[i]==","):
        list2.append(int(list1[index:i:1]))
        index=i+1
print (list2)
# Out:
# 1,12,13,2,2,
# [1, 12, 13, 2, 2]

# %%
#task1
list1=[]
for i in range (0,5,1):
  x=input()
  list1.append(x)
  print(list1)
# Out:
# 1
# ['1']
# 22
# ['1', '22']
# 33
# ['1', '22', '33']
# 142
# ['1', '22', '33', '142']
# 23
# ['1', '22', '33', '142', '23']

# %%
#task2
list1= input()
list2=[]
index=0
for i in range (0,len(list1),1):
    if(list1[i]==","):
        list2.append(int(list1[index:i:1]))
        index=i+1
if(len(list2)>=3):
  print (list2[2:len(list2)-1:1])
else:
  print("Not possible")
# Out:
# 1,2,3
# Not possible

# %%
#task3
k=[]
for i in range (1,6,1):
  k.append(int(input()))
j=k[::-1]
for l in j:
  print(l)
# Out:
# 5
# -5
# 100
# 1
# 0
# 0
# 1
# 100
# -5
# 5

# %%
#task4
x = [1, 2, 3, 4, 5, 6, 7]
y = []
for i in x:
  y.append(i**2)
print (y)
# Out:
# [1, 4, 9, 16, 25, 36, 49]

# %%
#task5
x=["hey", "there", "", "what's", "", "up", "", "?"]
y=[]
for i in x:
  if (i ==""):
    pass
  else:
    y.append(i)
print (y)
# Out:
# ['hey', 'there', "what's", 'up', '?']

# %%
#task6
j=input()
x= j.split(", ")
y=[]
cache=0
max=0
count=0
for i in range (0,len(x),1):
  if ((cache-int(x[i]))>0):
    max=cache
    index=i
  else:
    max=max
    cache=int(x[i])
for k in x:
  y.append(int(k))
print (f"My list:{y}")
print (f"Largest number in the list is {max} which was found at index {len(x)-i}.")
# Out:
# 7, 13, 2, 10, 6, -11, 0
# My list:[7, 13, 2, 10, 6, -11, 0]
# Largest number in the list is 13 which was found at index 1.

# %%
#Task 7
list_one = [1, 3, 5, 7, 9, 10]
list_two = [2, 4, 6, 8]
list_three=[]
for i in list_one[0:-1:1]:
  list_three.append(i)
for k in list_two[::1]:
  list_three.append(k)
print(list_three)
# Out:
# [1, 3, 5, 7, 9, 2, 4, 6, 8]

# %%
#task8
list_one = [1, 2, 3, 4, 5, 6, 7, 8, 9]
list_two = [10, 11, 12, -13, -14, -15, -16]
list_three=[]
list_four=[]
for i in list_one:
  list_three.append(i)
for k in list_two:
  list_three.append(k)
for j in list_three:
  if(j%2==0):
    list_four.append(j)
  else:
    pass
print(list_four)

# %%
#Task 9
list1= input()
list2=[]
list3=[]
index=0
list1=list1+" "
for i in range (0,len(list1),1):
    if(list1[i]==" "):
        list2.append(int(list1[index:i:1]))
        index=i+1
for j in list2:
  if j%2==0:
    pass
  else:
    list3.append(j)
print (f"Original list:{list2}")
print (f"Modified list: {list3}")
# Out:
# 7 12 4 55 96 2 11 61 33 42
# Original list:[7, 12, 4, 55, 96, 2, 11, 61, 33, 42]
# Modified list: [7, 55, 11, 61, 33]

# %%
#Task 10
list1= input()
list2=[]
list3=[]
index=0
for i in range (0,len(list1),1):
    if(list1[i]==","):
        list2.append(int(list1[index:i:1]))
        index=i+1
for l  in list2:
  if l in list2:
    if l in list3:
      pass
    else:
      list3.append(l)
  else:
    list3.append(l)   
print (f"Input list:{list2}")
print (f"Modified list:{list3}")
# Out:
# 7, 7, 7, 1, 0, 3, 3, 55, 9
# Input list:[7, 7, 7, 1, 0, 3, 3, 55]
# Modified list:[7, 1, 0, 3, 55]

# %%
#task11
List_one = [1, 4, 3, 2, 5]
List_two =  [8, 7, 6, 9]
istrue="False"
for i in List_one:
  if i in List_two:
    istrue="True"
  else:
    pass
print(istrue)
# Out:
# False
