# %%
#task1
num1 = int(input())
num2 = int(input())
print(f"sum{num1+num2}")
print (f"product{num1*num2}")
print (f"difference{num1-num2}")
# Out:
# 4
# 5
# sum9
# product20
# difference-1

# %%
#task2
import math 
r =float(input())
print (f"area is {math.pi*math.pow(r,2)}")
print (f"circumference is {math.pi*2*r}")
# Out:
# 5
# area is 78.53981633974483
# circumference is 31.41592653589793

# %%
#task3
X =float(input())
Y =float(input())
if(X>Y):
  print ("first is greater")
elif(Y>X):
  print ("Second is greater")
else:
  print ("The numbers are equal")
# Out:
# -44
# -5
# Second is greater

# %%
#task4
X =float(input())
Y =float(input())
if (X>Y):
  print (int(X-Y))
else:
  print (int(Y-X))
# Out:
# 6
# 55
# 49

# %%
#task5
X =float(input())
if(X%2==0):
  print ("The number is even")
else:
  print ("The number is odd")
# Out:
# 6
# The number is even

# %%
#task6
X =int(input())
if(X%2==0):
  print (X)
elif(X%5==0):
  print (X)
else:
  print("Not a multiple of 2 OR 5")
# Out:
# 7
# Not a multiple of 2 OR 5

# %%
 #task7
num =int(input())
if(num%2==0 and num%5==0):
  print ("Multiple of 2 and 5 both")
elif(num%2==0 and num%5!=0):
  print (num)
elif(num%2!=0 and num%5==0):
  print (num)
else:
  print ("Not a multiple we want")
# Out:
# 5
# 5

# %%
#task8
num =int(input())
if(num%2==0 and num%5==0):
  print (num)
else:
  print ("Not multiple of 2 and 5 both")
# Out:
# 30
# 30

# %%
#task9
ns =int(input())
H =ns//3600
M =((ns%3600)//60)
S =(ns%60)
print (f"Hours: {H} Minutes: {M} Seconds: {S}")
# Out:
# 300
# Hours: 0 Minutes: 5 Seconds: 0

# %%
#task10
H =int(input())
if(H>=0 and H<=168):
  if(H>=40):
    print (8000+((H-40)*300))
  else:
   print (H*200)
elif(H<0):
  print ("Hour cannot be negative")
elif(H>168):
  print ("Impossible to work more than 168 hours weekly")
# Out:
# 100
# 26000

# %%
#task11
S =int(input())
if(S<100):
  L =(3000-(125*(S**2)))
  print (L)
elif(S>=100):
  L =(12000/(4+((S**2)/14900)))
  print (L)
# Out:
# 120
# 2416.2162162162163

# %%
#task12
H =int(input())
if(H>=0 and H<24):
  if(H>=4 and H<=6):
    print ("Breakfast")
  elif(H>=12 and H<=13):
    print ("Lunch")
  elif(H>=16 and H<=17):
    print ("Snacks")
  elif(H>=19 and H<=20):
    print ("Dinner")
  elif(H<4 or H>20):
    print ("Patience is a virtue")
else:
  print ("Wrong time")
# Out:
# 23
# Patience is a virtue

# %%
#task13
M =int(input())
if(M>=0 and M<=100):
  if(M>=90):
    print ("A")
  elif(M>=80 and M<=89):
    print ("B")
  elif(M>=70 and M<=79):
    print ("C")
  elif(M>=60 and M<=69):
    print ("D")
  elif(M>=50 and M<=59):
    print ("E")
  elif(M<50):
    print ("F")
else:
  print ("number is not valid.")
# Out:
# 96
# A

# %%
#task14
s =float(input())
t =float(input())
v =((s/t)*3.6)
print (f"{v} km/h")
if(v<60):
  print ("Too slow. Needs more changes.")
elif(v>=60 and v<=90):
  print ("Velocity is okay. The car is ready!")
elif(v>90):
  print ("Too fast. Only a few changes should suffice.")
# Out:
# 160000
# 7200
# 80.0 km/h
# Velocity is okay. The car is ready!

# %%
#task15
cgpa =float(input("what is your cgpa?"))
cradit =float(input("plaease input your cradit number"))
gotship =0
numofper=0
if cradit>=30:
   if(cgpa>=3.80 and cgpa<=3.89):
    print ("25")
    gotship =1
    numofper=25
   elif(cgpa>=3.90 and cgpa<=3.94):
     print ("50")
     gotship =1
     numofper=50
   elif(cgpa>=3.95 and cgpa<=3.99):
     print ("75")
     gotship =1
     numofper=75
   elif(cgpa==4.00):
     print ("100")
     gotship =1
     numofper=100
   else:
     gotship=0
else:
   gotship=0
if(gotship==1):
   print (f"The student is eligible for a waiver of {numofper} percent.")
else:
   print ("The student is not eligible for a waiver")
# Out:
# 3.5
# 45
# The student is not eligible for a waiver

# %%
#TASK17
print (40 % 3)
# Out:
# 1
