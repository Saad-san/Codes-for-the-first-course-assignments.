# %%
#gg
print ("hello ","cc")
x =22
y =33
z =44
print (str(x),str(y),str(z))
# Out:
# hello  cc
# 22 33 44

# %%
#task1
print ("hello world")
# Out:
# hello world

# %%
#Task 2
print (54+64)
# Out:
# 118

# %%
#task3
season ="Fall"
year =2022
print (season)
print (year)
# Out:
# Fall
# 2022

# %%
#task4
name =input("please give your name")
print (name)
# Out:
# please give your nameJohn
# John

# %%
#task5
M =int(input("plz give M"))
print (int(M))
m =int(M)
N =int(input("plz give N"))
print (int(N))
n = int(N)
print (f"{M}^{N}:{m**n}")
# Out:
# plz give M2
# 2
# plz give N3
# 3
# 2^3:8

# %%
M =input()
M = int(M)
print(M*2)
# Out:
# 3
# 6

# %%
#Task 6
M =input("give your number")
y =(int(M) // 4)
print (y*4)
# Out:
# give your number11
# 8

# %%
#task7
A =float(input("A?"))
B =float(input("B?"))
C =float(input("C?"))
D =float(input("D?"))
X =(A**C)-(D/3)
Y =B*A
print (int(X+Y))
# Out:
# A?2
# B?6
# C?8
# D?1.3
# 267

# %%
#task8
N =int(input("how many chocolates do you have? "))
Y =(N //3)
print (Y)
print (f"Each friend will receive {Y} chocolates")
print (f"The number of remaining chocolates is {N - (Y*3)}")
# Out:
# how many chocolates do you have? 90
# 30
# Each friend will receive 30 chocolates
# The number of remaining chocolates is 0

# %%
#task9
M =input("value of M")
N =input("value of N")
print (M+N)
# Out:
# value of M2
# value of N3
# 23

# %%
#task10
line =input("line")
print(line[0])
# Out:
# linemy boy
# m

# %%
#task11
M =input("your number")
m =int(M)
print (m%2==0)
# Out:
# your number5
# False

# %%
s=input()
if(len(s)>=4):
 if((s[len(s)-2]+s[len(s)-1])=="er"):
  print (s[0:len(s)-2:1] +"est")
 elif ((s[len(s)-3]+s[len(s)-2]+s[len(s)-1])=="est"):
   print (s)
 else:
   print (s+"er")
else:
  print (s)
# Out:
# stronger
# strongest

# %%
s=input()
i=0
while(i<len(s)):
  print (s[0:i:1]+s[i])
  i+=1
# Out:
# dream
# d
# dr
# dre
# drea
# dream

# %%
s=input()
for i in s:
  print(i+":",ord(i))
# Out:
# hunger
# h: 104
# u: 117
# n: 110
# g: 103
# e: 101
# r: 114
